# %% [markdown]
# <a href="https://www.kaggle.com/code/spookyboogy/scop2?scriptVersionId=144610138" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 
import os

adata_obs_meta = pd.read_csv("/kaggle/input/open-problems-single-cell-perturbations/adata_obs_meta.csv")
adata_obs_meta.head()

# %%
de_train = pd.read_parquet('/kaggle/input/open-problems-single-cell-perturbations/de_train.parquet')
de_train.head()

id_map = pd.read_csv('/kaggle/input/open-problems-single-cell-perturbations/id_map.csv')
id_map.head()

multiome_obs_meta = pd.read_csv('/kaggle/input/open-problems-single-cell-perturbations/multiome_obs_meta.csv')
multiome_obs_meta.head()

multiome_var = pd.read_csv('/kaggle/input/open-problems-single-cell-perturbations/multiome_var_meta.csv')
multiome_var.head()

# %%
print(type(de_train))
mem = de_train.memory_usage()
memsum = mem.sum() / 1024 / 1024 / 1024
print(f'\n{mem}\n\n{memsum}\n')
dir(de_train)[:10]

# %%
adata_train = pd.read_parquet('/kaggle/input/open-problems-single-cell-perturbations/adata_train.parquet')
adata_train.head()

# %%
multiome_train = pd.read_parquet('/kaggle/input/open-problems-single-cell-perturbations/multiome_train.parquet')
multiome_train.head()
